# %% [markdown]
# # Data Wrangling

# %% [markdown]
# In this section we will look into analyzing relatively large sets of data using Pandas.
#
# We will use our data manipulation and analysis skills to analyze weekly Covid-19 data provided by John Hopkins University.

# %% [markdown]
# ## The Input Data

# %% [markdown]
# John Hopkins provides a data repository which contains the daily Covid-19 metrics aggregated from a variety of sources including World Health Organization, European Centre for Disease Prevention and Control, US CDC, and public health departments of various states and counties. The popular 2019 Novel Coronavirus Visual Dashboard (https://www.arcgis.com/apps/opsdashboard/index.html#/bda7594740fd40299423467b48e9ecf6) is powered by this large data repository.
# You can download the dataset from https://github.com/CSSEGISandData/COVID-19. We are going to use the daily report data aggregated at the level of states.

# %% [markdown]
# ## Reading the Data

# %% [markdown]
# Let us first read a single file from the folder csse_covid_19_daily_reports_us to get an idea about the structure of the data.

# %%
# First we import pandas
import pandas as pd

# %%
#read the file 01-01-2021.csv from the csse_covid_19_daily_reports_us folder
sampledata = pd.read_csv('../../largedatasets/csse_covid_19_daily_reports_us/01-01-2021.csv')

# %%
#let's see the first five records
sampledata.head()
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 0         Alabama             US  2021-01-02 05:30:44  32.3182  -86.9023
# 1          Alaska             US  2021-01-02 05:30:44  61.3707 -152.4044
# 2  American Samoa             US  2021-01-02 05:30:44 -14.2710 -170.1320
# 3         Arizona             US  2021-01-02 05:30:44  33.7298 -111.4312
# 4        Arkansas             US  2021-01-02 05:30:44  34.9697  -92.3731
#
#    Confirmed  Deaths  Recovered    Active  FIPS  ...  Total_Test_Results  \
# 0     365747    4872   202137.0  158738.0   1.0  ...                 NaN
# 1      47019     206     7165.0   39648.0   2.0  ...           1275750.0
# 2          0       0        NaN       NaN  60.0  ...              2140.0
# 3     530267    9015    76934.0  444318.0   4.0  ...           5155330.0
# 4     229442    3711   199247.0   26484.0   5.0  ...           2051488.0
#
#    People_Hospitalized  Case_Fatality_Ratio         UID  ISO3   Testing_Rate  \
# 0                  NaN             1.332068  84000001.0   USA            NaN
# 1                  NaN             0.438121  84000002.0   USA  174391.185778
# 2                  NaN                  NaN        16.0   ASM    3846.084722
# 3                  NaN             1.700087  84000004.0   USA   39551.860582
# 4                  NaN             1.617402  84000005.0   USA   67979.497674
#
#    Hospitalization_Rate        Date People_Tested  Mortality_Rate
# 0                   NaN  2021-01-01           NaN             NaN
# 1                   NaN  2021-01-01           NaN             NaN
# 2                   NaN  2021-01-01           NaN             NaN
# 3                   NaN  2021-01-01           NaN             NaN
# 4                   NaN  2021-01-01           NaN             NaN
#
# [5 rows x 21 columns]

# %%
#how many rows columns
sampledata.shape
# Out:
# (58, 21)

# %%
#List the columns
sampledata.columns
# Out:
# Index(['Province_State', 'Country_Region', 'Last_Update', 'Lat', 'Long_',
#        'Confirmed', 'Deaths', 'Recovered', 'Active', 'FIPS', 'Incident_Rate',
#        'Total_Test_Results', 'People_Hospitalized', 'Case_Fatality_Ratio',
#        'UID', 'ISO3', 'Testing_Rate', 'Hospitalization_Rate', 'Date',
#        'People_Tested', 'Mortality_Rate'],
#       dtype='object')

# %% [markdown]
# Let's check the record for Ohio

# %%
sampledata[sampledata['Province_State']=='Ohio']
# Out:
#    Province_State Country_Region          Last_Update      Lat    Long_  \
# 40           Ohio             US  2021-01-02 05:30:44  40.3888 -82.7649
#
#     Confirmed  Deaths  Recovered    Active  FIPS  ...  Total_Test_Results  \
# 40     700380   13766   556106.0  130508.0  39.0  ...           8757248.0
#
#     People_Hospitalized  Case_Fatality_Ratio         UID  ISO3 Testing_Rate  \
# 40                  NaN             1.965504  84000039.0   USA     0.000007
#
#     Hospitalization_Rate        Date People_Tested  Mortality_Rate
# 40                   NaN  2021-01-01           NaN             NaN
#
# [1 rows x 21 columns]

# %% [markdown]
# ## Reading multiple files from a folder

# %% [markdown]
# Many a times you might need to combine data from multiple files and then perform some analysis on the combined data. Python has a library called glob which helps to find out all pathnames matching a specified pattern. Let's try to list all the csv files in the folder csse_covid_19_daily_reports_us

# %%
#First we need to import the library glob
import glob
#then we use the glob function in the glob library to search for all files that match the pattern *.csv in the folder csse_covid_19_daily_reports_us
allFiles = glob.glob('../../largedatasets/csse_covid_19_daily_reports_us/*.csv')
#print the first 10 file paths
allFiles[0:10]
# Out:
# ['../../largedatasets/csse_covid_19_daily_reports_us\\01-01-2021.csv',
#  '../../largedatasets/csse_covid_19_daily_reports_us\\01-01-2022.csv',
#  '../../largedatasets/csse_covid_19_daily_reports_us\\01-02-2021.csv',
#  '../../largedatasets/csse_covid_19_daily_reports_us\\01-02-2022.csv',
#  '../../largedatasets/csse_covid_19_daily_reports_us\\01-03-2021.csv',
#  '../../largedatasets/csse_covid_19_daily_reports_us\\01-03-2022.csv',
#  '../../largedatasets/csse_covid_19_daily_reports_us\\01-04-2021.csv',
#  '../../largedatasets/csse_covid_19_daily_reports_us\\01-04-2022.csv',
#  '../../largedatasets/csse_covid_19_daily_reports_us\\01-05-2021.csv',
#  '../../largedatasets/csse_covid_19_daily_reports_us\\01-05-2022.csv']

# %% [markdown]
# ## Combining multiple DataFrames to a single DataFrame

# %% [markdown]
# We can use the concat() function in the Pandas library to combine multiple DataFrames. Let's see the details of concat function using the '?' operator

# %% [markdown]
# ![concat](images/concat.png)

# %%
pd.concat?

# %% [markdown]
# So concat() function accepts a sequence of DataFrames/Series and then concatenate them along a specified axis (index or columns)
#
# Our plan is to
# 1) Loop through each pathnames stored in allFiles and read them into a DataFrame using read_csv() function.
# 2) Save all DataFrames into a list.
# 3) Use pd.concat to create a single DataFrame from all the DataFrames

# %%
# an empty list to store the DataFrames
allDataFrames = []
# now we will loop through each filepath and read them into DataFrames
for fileName in allFiles:
    #read the file using pandas
    data = pd.read_csv(fileName)
    #store the DataFrame to the list
    allDataFrames.append(data)
#now we apply pd.concat to create a single DataFrame containing all the records. We will use the same variable name as the list
allDataFrames = pd.concat(allDataFrames,ignore_index=True)

# %%
allDataFrames.shape
# Out:
# (57322, 21)

# %% [markdown]
# So there are 57,322 records in our combined dataset.
#
# Let's use the describe function to see some basic stats about the combined dataset.

# %%
allDataFrames.describe()

# %% [markdown]
# Let us look at the datatypes for the columns

# %%
allDataFrames.dtypes

# %% [markdown]
# ## Parsing Dates

# %% [markdown]
# Currently the date column that is available in the dataset is 'Date'. If you check the datatype for the 'Last_Update' column (using dtype), you can see that it is in string format. This might not be particularly helpful if you want to filter/aggregate the data based on various time granularities (day,week,month,year etc.). Pandas has a function called to_datetime, which can convert string to datetime object. Let us try out pd.to_datetime.

# %%
pd.to_datetime?

# %%
allDataFrames['Date_converted'] = pd.to_datetime(allDataFrames['Date'])

# %% [markdown]
# Let's check the datatype for the new column that we have created

# %%
allDataFrames['Date_converted']
# Out:
# 0       2021-01-01
# 1       2021-01-01
# 2       2021-01-01
# 3       2021-01-01
# 4       2021-01-01
#            ...
# 57317   2021-12-31
# 57318   2021-12-31
# 57319   2021-12-31
# 57320   2021-12-31
# 57321   2021-12-31
# Name: Date_converted, Length: 57322, dtype: datetime64[ns]

# %% [markdown]
# Now we could easily filter the dataset based on this new column. For example filter out all the records for the year 2021.

# %%
allDataFrames[allDataFrames['Date_converted'].dt.year==2021]
# Out:
#        Province_State Country_Region          Last_Update      Lat     Long_  \
# 0             Alabama             US  2021-01-02 05:30:44  32.3182  -86.9023
# 1              Alaska             US  2021-01-02 05:30:44  61.3707 -152.4044
# 2      American Samoa             US  2021-01-02 05:30:44 -14.2710 -170.1320
# 3             Arizona             US  2021-01-02 05:30:44  33.7298 -111.4312
# 4            Arkansas             US  2021-01-02 05:30:44  34.9697  -92.3731
# ...               ...            ...                  ...      ...       ...
# 57317        Virginia             US  2022-01-01 04:32:44  37.7693  -78.1700
# 57318      Washington             US  2022-01-01 04:32:44  47.4009 -121.4905
# 57319   West Virginia             US  2022-01-01 04:32:44  38.4912  -80.9545
# 57320       Wisconsin             US  2022-01-01 04:32:44  44.2685  -89.6165
# 57321         Wyoming             US  2022-01-01 04:32:44  42.7560 -107.3025
#
#        Confirmed  Deaths  Recovered    Active  FIPS  ...  People_Hospitalized  \
# 0         365747    4872   202137.0  158738.0   1.0  ...                  NaN
# 1          47019     206     7165.0   39648.0   2.0  ...                  NaN
# 2              0       0        NaN       NaN  60.0  ...                  NaN
# 3         530267    9015    76934.0  444318.0   4.0  ...                  NaN
# 4         229442    3711   199247.0   26484.0   5.0  ...                  NaN
# ...          ...     ...        ...       ...   ...  ...                  ...
# 57317    1118518   15587        NaN       NaN  51.0  ...                  NaN
# 57318     849075    9853        NaN       NaN  53.0  ...                  NaN
# 57319     328162    5336        NaN       NaN  54.0  ...                  NaN
# 57320    1120663   11173        NaN       NaN  55.0  ...                  NaN
# 57321     115638    1526        NaN       NaN  56.0  ...                  NaN
#
#        Case_Fatality_Ratio         UID  ISO3   Testing_Rate  \
# 0                 1.332068  84000001.0   USA            NaN
# 1                 0.438121  84000002.0   USA  174391.185778
# 2                      NaN        16.0   ASM    3846.084722
# 3                 1.700087  84000004.0   USA   39551.860582
# 4                 1.617402  84000005.0   USA   67979.497674
# ...                    ...         ...   ...            ...
# 57317             1.393540  84000051.0   USA  130970.524464
# 57318             1.160439  84000053.0   USA  130778.607132
# 57319             1.626026  84000054.0   USA  275536.772374
# 57320             0.996999  84000055.0   USA       0.000023
# 57321             1.319635  84000056.0   USA  207721.348610
#
#       Hospitalization_Rate        Date  People_Tested Mortality_Rate  \
# 0                      NaN  2021-01-01            NaN            NaN
# 1                      NaN  2021-01-01            NaN            NaN
# 2                      NaN  2021-01-01            NaN            NaN
# 3                      NaN  2021-01-01            NaN            NaN
# 4                      NaN  2021-01-01            NaN            NaN
# ...                    ...         ...            ...            ...
# 57317                  NaN  2021-12-31            NaN            NaN
# 57318                  NaN  2021-12-31            NaN            NaN
# 57319                  NaN  2021-12-31            NaN            NaN
# 57320                  NaN  2021-12-31            NaN            NaN
# 57321                  NaN  2021-12-31            NaN            NaN
#
#        Date_converted
# 0          2021-01-01
# 1          2021-01-01
# 2          2021-01-01
# 3          2021-01-01
# 4          2021-01-01
# ...               ...
# 57317      2021-12-31
# 57318      2021-12-31
# 57319      2021-12-31
# 57320      2021-12-31
# 57321      2021-12-31
#
# [21170 rows x 22 columns]

# %% [markdown]
# Or for January 2021

# %%
allDataFrames[(allDataFrames['Date_converted'].dt.year==2021)&(allDataFrames['Date_converted'].dt.month==1)]
# Out:
#       Province_State Country_Region          Last_Update      Lat     Long_  \
# 0            Alabama             US  2021-01-02 05:30:44  32.3182  -86.9023
# 1             Alaska             US  2021-01-02 05:30:44  61.3707 -152.4044
# 2     American Samoa             US  2021-01-02 05:30:44 -14.2710 -170.1320
# 3            Arizona             US  2021-01-02 05:30:44  33.7298 -111.4312
# 4           Arkansas             US  2021-01-02 05:30:44  34.9697  -92.3731
# ...              ...            ...                  ...      ...       ...
# 3533        Virginia             US  2021-02-01 05:30:44  37.7693  -78.1700
# 3534      Washington             US  2021-02-01 05:30:44  47.4009 -121.4905
# 3535   West Virginia             US  2021-02-01 05:30:44  38.4912  -80.9545
# 3536       Wisconsin             US  2021-02-01 05:30:44  44.2685  -89.6165
# 3537         Wyoming             US  2021-02-01 05:30:44  42.7560 -107.3025
#
#       Confirmed  Deaths  Recovered    Active  FIPS  ...  People_Hospitalized  \
# 0        365747    4872   202137.0  158738.0   1.0  ...                  NaN
# 1         47019     206     7165.0   39648.0   2.0  ...                  NaN
# 2             0       0        NaN       NaN  60.0  ...                  NaN
# 3        530267    9015    76934.0  444318.0   4.0  ...                  NaN
# 4        229442    3711   199247.0   26484.0   5.0  ...                  NaN
# ...         ...     ...        ...       ...   ...  ...                  ...
# 3533     504779    6464    40322.0  457993.0  51.0  ...                  NaN
# 3534     311597    4285        NaN       NaN  53.0  ...                  NaN
# 3535     121001    2024    97782.0   21195.0  54.0  ...                  NaN
# 3536     592140    6434   517169.0   68537.0  55.0  ...                  NaN
# 3537      51912     596    50003.0    1313.0  56.0  ...                  NaN
#
#       Case_Fatality_Ratio         UID  ISO3   Testing_Rate  \
# 0                1.332068  84000001.0   USA            NaN
# 1                0.438121  84000002.0   USA  174391.185778
# 2                     NaN        16.0   ASM    3846.084722
# 3                1.700087  84000004.0   USA   39551.860582
# 4                1.617402  84000005.0   USA   67979.497674
# ...                   ...         ...   ...            ...
# 3533             1.280560  84000051.0   USA   61322.047318
# 3534             1.375174  84000053.0   USA   59728.206293
# 3535             1.672713  84000054.0   USA  108561.351273
# 3536             1.086567  84000055.0   USA       0.000011
# 3537             1.148097  84000056.0   USA  109714.924520
#
#      Hospitalization_Rate        Date  People_Tested Mortality_Rate  \
# 0                     NaN  2021-01-01            NaN            NaN
# 1                     NaN  2021-01-01            NaN            NaN
# 2                     NaN  2021-01-01            NaN            NaN
# 3                     NaN  2021-01-01            NaN            NaN
# 4                     NaN  2021-01-01            NaN            NaN
# ...                   ...         ...            ...            ...
# 3533                  NaN  2021-01-31            NaN            NaN
# 3534                  NaN  2021-01-31            NaN            NaN
# 3535                  NaN  2021-01-31            NaN            NaN
# 3536                  NaN  2021-01-31            NaN            NaN
# 3537                  NaN  2021-01-31            NaN            NaN
#
#       Date_converted
# 0         2021-01-01
# 1         2021-01-01
# 2         2021-01-01
# 3         2021-01-01
# 4         2021-01-01
# ...              ...
# 3533      2021-01-31
# 3534      2021-01-31
# 3535      2021-01-31
# 3536      2021-01-31
# 3537      2021-01-31
#
# [1798 rows x 22 columns]

# %% [markdown]
# Or between January 01 2021 and Decemeber 31 2021 (yearly)

# %%
allDataFrames[(allDataFrames['Date_converted']>='2021-01-01')&(allDataFrames['Date_converted']<='2021-12-31')]
# Out:
#        Province_State Country_Region          Last_Update      Lat     Long_  \
# 0             Alabama             US  2021-01-02 05:30:44  32.3182  -86.9023
# 1              Alaska             US  2021-01-02 05:30:44  61.3707 -152.4044
# 2      American Samoa             US  2021-01-02 05:30:44 -14.2710 -170.1320
# 3             Arizona             US  2021-01-02 05:30:44  33.7298 -111.4312
# 4            Arkansas             US  2021-01-02 05:30:44  34.9697  -92.3731
# ...               ...            ...                  ...      ...       ...
# 57317        Virginia             US  2022-01-01 04:32:44  37.7693  -78.1700
# 57318      Washington             US  2022-01-01 04:32:44  47.4009 -121.4905
# 57319   West Virginia             US  2022-01-01 04:32:44  38.4912  -80.9545
# 57320       Wisconsin             US  2022-01-01 04:32:44  44.2685  -89.6165
# 57321         Wyoming             US  2022-01-01 04:32:44  42.7560 -107.3025
#
#        Confirmed  Deaths  Recovered    Active  FIPS  ...  People_Hospitalized  \
# 0         365747    4872   202137.0  158738.0   1.0  ...                  NaN
# 1          47019     206     7165.0   39648.0   2.0  ...                  NaN
# 2              0       0        NaN       NaN  60.0  ...                  NaN
# 3         530267    9015    76934.0  444318.0   4.0  ...                  NaN
# 4         229442    3711   199247.0   26484.0   5.0  ...                  NaN
# ...          ...     ...        ...       ...   ...  ...                  ...
# 57317    1118518   15587        NaN       NaN  51.0  ...                  NaN
# 57318     849075    9853        NaN       NaN  53.0  ...                  NaN
# 57319     328162    5336        NaN       NaN  54.0  ...                  NaN
# 57320    1120663   11173        NaN       NaN  55.0  ...                  NaN
# 57321     115638    1526        NaN       NaN  56.0  ...                  NaN
#
#        Case_Fatality_Ratio         UID  ISO3   Testing_Rate  \
# 0                 1.332068  84000001.0   USA            NaN
# 1                 0.438121  84000002.0   USA  174391.185778
# 2                      NaN        16.0   ASM    3846.084722
# 3                 1.700087  84000004.0   USA   39551.860582
# 4                 1.617402  84000005.0   USA   67979.497674
# ...                    ...         ...   ...            ...
# 57317             1.393540  84000051.0   USA  130970.524464
# 57318             1.160439  84000053.0   USA  130778.607132
# 57319             1.626026  84000054.0   USA  275536.772374
# 57320             0.996999  84000055.0   USA       0.000023
# 57321             1.319635  84000056.0   USA  207721.348610
#
#       Hospitalization_Rate        Date  People_Tested Mortality_Rate  \
# 0                      NaN  2021-01-01            NaN            NaN
# 1                      NaN  2021-01-01            NaN            NaN
# 2                      NaN  2021-01-01            NaN            NaN
# 3                      NaN  2021-01-01            NaN            NaN
# 4                      NaN  2021-01-01            NaN            NaN
# ...                    ...         ...            ...            ...
# 57317                  NaN  2021-12-31            NaN            NaN
# 57318                  NaN  2021-12-31            NaN            NaN
# 57319                  NaN  2021-12-31            NaN            NaN
# 57320                  NaN  2021-12-31            NaN            NaN
# 57321                  NaN  2021-12-31            NaN            NaN
#
#        Date_converted
# 0          2021-01-01
# 1          2021-01-01
# 2          2021-01-01
# 3          2021-01-01
# 4          2021-01-01
# ...               ...
# 57317      2021-12-31
# 57318      2021-12-31
# 57319      2021-12-31
# 57320      2021-12-31
# 57321      2021-12-31
#
# [21170 rows x 22 columns]

# %% [markdown]
# ## Aggregating Data using Grouping (groupby)

# %% [markdown]
# Categorizing a dataset into groups and then applying a function to each group can be a critical component of a data analysis workflow.
#
# You can think of Grouping Operations in Pandas as a combination of split-apply-combine. In the first stage of the process, data contained in a pandas object (DataFrame/Series), is split into groups based on one or more keys that you provide. Once this is done, a function is applied to each group, producing a new value. Finally, the results of all those function applications are combined into a result object.
#
# The figure shown below gives you a better idea about the split-apply-combine paradigm.
#
# ![split-apply-combine](images/split-apply-combine.png)

# %% [markdown]
# In pandas we use the groupby() method to group a DataFrame/Series based on a key or a combination of keys. Let's group our dataset based on state name (Province_State).

# %%
stateGroups = allDataFrames.groupby('Province_State')

# %% [markdown]
# We can check the number of groups using the len() function

# %%
len(stateGroups)
# Out:
# 59

# %% [markdown]
# You can loop through each group using a for loop.

# %%
for key, group in stateGroups:
    print ('This is the',key,'group and it has',len(group),'records')
# Out:
# This is the Alabama group and it has 988 records
# This is the Alaska group and it has 988 records
# This is the American Samoa group and it has 988 records
# This is the Arizona group and it has 988 records
# This is the Arkansas group and it has 988 records
# This is the California group and it has 988 records
# This is the Colorado group and it has 988 records
# This is the Connecticut group and it has 988 records
# This is the Delaware group and it has 988 records
# This is the Diamond Princess group and it has 988 records
# This is the District of Columbia group and it has 988 records
# This is the Florida group and it has 988 records
# This is the Georgia group and it has 988 records
# This is the Grand Princess group and it has 988 records
# This is the Guam group and it has 988 records
# This is the Hawaii group and it has 988 records
# This is the Idaho group and it has 988 records
# This is the Illinois group and it has 988 records
# This is the Indiana group and it has 988 records
# This is the Iowa group and it has 988 records
# This is the Kansas group and it has 988 records
# This is the Kentucky group and it has 988 records
# This is the Louisiana group and it has 988 records
# This is the Maine group and it has 988 records
# This is the Maryland group and it has 988 records
# This is the Massachusetts group and it has 988 records
# This is the Michigan group and it has 988 records
# This is the Minnesota group and it has 988 records
# This is the Mississippi group and it has 988 records
# This is the Missouri group and it has 988 records
# This is the Montana group and it has 988 records
# This is the Nebraska group and it has 988 records
# This is the Nevada group and it has 988 records
# This is the New Hampshire group and it has 988 records
# This is the New Jersey group and it has 988 records
# This is the New Mexico group and it has 988 records
# This is the New York group and it has 988 records
# This is the North Carolina group and it has 988 records
# This is the North Dakota group and it has 988 records
# This is the Northern Mariana Islands group and it has 988 records
# This is the Ohio group and it has 988 records
# This is the Oklahoma group and it has 988 records
# This is the Oregon group and it has 988 records
# This is the Pennsylvania group and it has 988 records
# This is the Puerto Rico group and it has 988 records
# This is the Recovered group and it has 18 records
# This is the Rhode Island group and it has 988 records
# This is the South Carolina group and it has 988 records
# This is the South Dakota group and it has 988 records
# This is the Tennessee group and it has 988 records
# This is the Texas group and it has 988 records
# This is the Utah group and it has 988 records
# This is the Vermont group and it has 988 records
# This is the Virgin Islands group and it has 988 records
# This is the Virginia group and it has 988 records
# This is the Washington group and it has 988 records
# This is the West Virginia group and it has 988 records
# This is the Wisconsin group and it has 988 records
# This is the Wyoming group and it has 988 records

# %% [markdown]
# You might be confused with the two loop variables (until now we have only seen one loop variable). This is possible. Let's see a small example.

# %%
# a list of list
records = [[1,'John'],[10,'Jay'],[34,'Sam']]
# now we can use two loop variables
for idValue,name in records:
    print (idValue,'-->',name)
# Out:
# 1 --> John
# 10 --> Jay
# 34 --> Sam

# %% [markdown]
# Back to our groupby example. We can retrieve individual group using get_group() method. Lets retrieve the Ohio group

# %%
ohGroup = stateGroups.get_group('Ohio')

# %% [markdown]
# Can you show another way to retrieve all the records from Ohio

# %% [markdown]
# If we want to calculate the total number of deaths in Ohio, we should just retrieve the maximum value for death as the data is cumulative.

# %%
ohGroup['Deaths'].max()
# Out:
# 40840

# %% [markdown]
# We can also apply the same logic and retrive the total number of deaths for all the states by applying the max() method to the entire group.

# %%
stateGroups['Deaths'].max()
# Out:
# Province_State
# Alabama                     20737
# Alaska                       1455
# American Samoa                 39
# Arizona                     32038
# Arkansas                    12682
# California                  98385
# Colorado                    13841
# Connecticut                 11733
# Delaware                     3205
# Diamond Princess                0
# District of Columbia         1411
# Florida                     83606
# Georgia                     41361
# Grand Princess                  3
# Guam                          411
# Hawaii                       1758
# Idaho                        5303
# Illinois                    40610
# Indiana                     25303
# Iowa                        10389
# Kansas                       9709
# Kentucky                    17625
# Louisiana                   18345
# Maine                        2779
# Maryland                    15905
# Massachusetts               22793
# Michigan                    40657
# Minnesota                   14273
# Mississippi                 13083
# Missouri                    22209
# Montana                      3617
# Nebraska                     4684
# Nevada                      11705
# New Hampshire                2851
# New Jersey                  35425
# New Mexico                   8788
# New York                    74845
# North Carolina              27629
# North Dakota                 2422
# Northern Mariana Islands       41
# Ohio                        40840
# Oklahoma                    17383
# Oregon                       8948
# Pennsylvania                48798
# Puerto Rico                  5506
# Recovered                       0
# Rhode Island                 3777
# South Carolina              18811
# South Dakota                 3116
# Tennessee                   28545
# Texas                       91716
# Utah                         5177
# Vermont                       791
# Virgin Islands                127
# Virginia                    22649
# Washington                  14991
# West Virginia                7661
# Wisconsin                   15767
# Wyoming                      1958
# Name: Deaths, dtype: int64

# %% [markdown]
# And then sort them by value

# %%
stateGroups['Deaths'].max().sort_values(ascending=False)
# Out:
# Province_State
# California                  98385
# Texas                       91716
# Florida                     83606
# New York                    74845
# Pennsylvania                48798
# Georgia                     41361
# Ohio                        40840
# Michigan                    40657
# Illinois                    40610
# New Jersey                  35425
# Arizona                     32038
# Tennessee                   28545
# North Carolina              27629
# Indiana                     25303
# Massachusetts               22793
# Virginia                    22649
# Missouri                    22209
# Alabama                     20737
# South Carolina              18811
# Louisiana                   18345
# Kentucky                    17625
# Oklahoma                    17383
# Maryland                    15905
# Wisconsin                   15767
# Washington                  14991
# Minnesota                   14273
# Colorado                    13841
# Mississippi                 13083
# Arkansas                    12682
# Connecticut                 11733
# Nevada                      11705
# Iowa                        10389
# Kansas                       9709
# Oregon                       8948
# New Mexico                   8788
# West Virginia                7661
# Puerto Rico                  5506
# Idaho                        5303
# Utah                         5177
# Nebraska                     4684
# Rhode Island                 3777
# Montana                      3617
# Delaware                     3205
# South Dakota                 3116
# New Hampshire                2851
# Maine                        2779
# North Dakota                 2422
# Wyoming                      1958
# Hawaii                       1758
# Alaska                       1455
# District of Columbia         1411
# Vermont                       791
# Guam                          411
# Virgin Islands                127
# Northern Mariana Islands       41
# American Samoa                 39
# Grand Princess                  3
# Recovered                       0
# Diamond Princess                0
# Name: Deaths, dtype: int64

# %%
ohGroup.tail()
# Out:
#       Province_State Country_Region          Last_Update      Lat    Long_  \
# 57072           Ohio             US  2021-12-30 04:33:59  40.3888 -82.7649
# 57130           Ohio             US  2020-12-31 05:30:27  40.3888 -82.7649
# 57188           Ohio             US  2021-12-31 04:33:06  40.3888 -82.7649
# 57246           Ohio             US  2021-01-01 05:30:27  40.3888 -82.7649
# 57304           Ohio             US  2022-01-01 04:32:44  40.3888 -82.7649
#
#        Confirmed  Deaths  Recovered    Active  FIPS  ...  People_Hospitalized  \
# 57072    1975723   31637        NaN       NaN  39.0  ...                  NaN
# 57130     690748   13469   546305.0  130974.0  39.0  ...                  NaN
# 57188    1995497   31770        NaN       NaN  39.0  ...                  NaN
# 57246     700380   13621   556106.0  130653.0  39.0  ...                  NaN
# 57304    2016082   31898        NaN       NaN  39.0  ...                  NaN
#
#        Case_Fatality_Ratio         UID  ISO3  Testing_Rate  \
# 57072             1.596580  84000039.0   USA      0.000022
# 57130             1.949915  84000039.0   USA      0.000007
# 57188             1.587474  84000039.0   USA      0.000022
# 57246             1.944801  84000039.0   USA      0.000007
# 57304             1.577565  84000039.0   USA      0.000022
#
#       Hospitalization_Rate        Date  People_Tested Mortality_Rate  \
# 57072                  NaN  2021-12-29            NaN            NaN
# 57130                  NaN  2020-12-30            NaN            NaN
# 57188                  NaN  2021-12-30            NaN            NaN
# 57246                  NaN  2020-12-31            NaN            NaN
# 57304                  NaN  2021-12-31            NaN            NaN
#
#        Date_converted
# 57072      2021-12-29
# 57130      2020-12-30
# 57188      2021-12-30
# 57246      2020-12-31
# 57304      2021-12-31
#
# [5 rows x 22 columns]

# %% [markdown]
# Now can you do the same for the confirmed cases.

# %% [markdown]
# Since we have cumulative totals for deaths, what if we want to see daily totals. For this we can use the diff() method which can be used to subtract values with in certain periods. But before applying this method we need to make sure that the data is sorted by value.

# %%
ohGroup_sorted = ohGroup.sort_values(by='Deaths')

# %%
ohGroup_sorted['Deaths'].diff()
# Out:
# 11756     NaN
# 11931    36.0
# 12106    35.0
# 12281    36.0
# 12456    34.0
#          ...
# 55390     0.0
# 55216     0.0
# 55042     0.0
# 56608     0.0
# 55912     0.0
# Name: Deaths, Length: 988, dtype: float64

# %% [markdown]
# You can add this as a new column in the group

# %%
ohGroup_sorted['Daily_Deaths_Total'] = ohGroup_sorted['Deaths'].diff()

# %%
ohGroup_sorted
# Out:
#       Province_State Country_Region          Last_Update      Lat    Long_  \
# 11756           Ohio             US  2020-04-12 23:18:15  40.3888 -82.7649
# 11931           Ohio             US  2020-04-13 23:07:54  40.3888 -82.7649
# 12106           Ohio             US  2020-04-14 23:33:31  40.3888 -82.7649
# 12281           Ohio             US  2020-04-15 22:56:51  40.3888 -82.7649
# 12456           Ohio             US  2020-04-16 23:30:51  40.3888 -82.7649
# ...              ...            ...                  ...      ...      ...
# 55390           Ohio             US  2022-12-19 04:31:41  40.3888 -82.7649
# 55216           Ohio             US  2022-12-18 04:31:17  40.3888 -82.7649
# 55042           Ohio             US  2022-12-17 04:32:17  40.3888 -82.7649
# 56608           Ohio             US  2022-12-26 04:31:20  40.3888 -82.7649
# 55912           Ohio             US  2022-12-22 04:31:45  40.3888 -82.7649
#
#        Confirmed  Deaths  Recovered  Active  FIPS  ...  Case_Fatality_Ratio  \
# 11756       6604     363        NaN     NaN  39.0  ...                  NaN
# 11931       6975     399        NaN     NaN  39.0  ...                  NaN
# 12106       7285     434        NaN     NaN  39.0  ...                  NaN
# 12281       7794     470        NaN     NaN  39.0  ...                  NaN
# 12456       8414     504        NaN     NaN  39.0  ...                  NaN
# ...          ...     ...        ...     ...   ...  ...                  ...
# 55390    3276630   40840        NaN     NaN  39.0  ...             1.243564
# 55216    3276630   40840        NaN     NaN  39.0  ...             1.243564
# 55042    3276630   40840        NaN     NaN  39.0  ...             1.243564
# 56608    3294521   40840        NaN     NaN  39.0  ...             1.239634
# 55912    3276630   40840        NaN     NaN  39.0  ...             1.243564
#
#               UID  ISO3  Testing_Rate  Hospitalization_Rate        Date  \
# 11756  84000039.0   USA  5.973514e-08             29.497274  2020-04-12
# 11931  84000039.0   USA  6.187559e-08             29.146953  2020-04-13
# 12106  84000039.0   USA  6.496651e-08             29.595058  2020-04-14
# 12281  84000039.0   USA  6.839449e-08             28.701565  2020-04-15
# 12456  84000039.0   USA  7.171125e-08             27.703827  2020-04-16
# ...           ...   ...           ...                   ...         ...
# 55390  84000039.0   USA           NaN                   NaN         NaN
# 55216  84000039.0   USA           NaN                   NaN         NaN
# 55042  84000039.0   USA           NaN                   NaN         NaN
# 56608  84000039.0   USA           NaN                   NaN         NaN
# 55912  84000039.0   USA           NaN                   NaN         NaN
#
#        People_Tested  Mortality_Rate Date_converted  Daily_Deaths_Total
# 11756        63243.0        5.496669     2020-04-12                 NaN
# 11931        65112.0        5.720430     2020-04-13                36.0
# 12106        67874.0        5.957447     2020-04-14                35.0
# 12281        71552.0        6.030280     2020-04-15                36.0
# 12456        74840.0        5.990017     2020-04-16                34.0
# ...              ...             ...            ...                 ...
# 55390            NaN             NaN            NaT                 0.0
# 55216            NaN             NaN            NaT                 0.0
# 55042            NaN             NaN            NaT                 0.0
# 56608            NaN             NaN            NaT                 0.0
# 55912            NaN             NaN            NaT                 0.0
#
# [988 rows x 23 columns]

# %% [markdown]
# Now you can find out the day with most number of deaths in Ohio

# %%
ohGroup_sorted.sort_values(by='Daily_Deaths_Total',ascending=False)
# Out:
#       Province_State Country_Region          Last_Update      Lat    Long_  \
# 54926           Ohio             US  2020-12-17 05:30:43  40.3888 -82.7649
# 55274           Ohio             US  2020-12-19 05:30:27  40.3888 -82.7649
# 55100           Ohio             US  2020-12-18 05:30:33  40.3888 -82.7649
# 55970           Ohio             US  2020-12-23 05:30:33  40.3888 -82.7649
# 53882           Ohio             US  2020-12-11 05:30:31  40.3888 -82.7649
# ...              ...            ...                  ...      ...      ...
# 55216           Ohio             US  2022-12-18 04:31:17  40.3888 -82.7649
# 55042           Ohio             US  2022-12-17 04:32:17  40.3888 -82.7649
# 56608           Ohio             US  2022-12-26 04:31:20  40.3888 -82.7649
# 55912           Ohio             US  2022-12-22 04:31:45  40.3888 -82.7649
# 11756           Ohio             US  2020-04-12 23:18:15  40.3888 -82.7649
#
#        Confirmed  Deaths  Recovered    Active  FIPS  ...  Case_Fatality_Ratio  \
# 54926     584766   10979   416028.0  157759.0  39.0  ...             1.877503
# 55274     605862   11396   430621.0  163845.0  39.0  ...             1.880956
# 55100     596178   11187   426525.0  158466.0  39.0  ...             1.876453
# 55970     637032   12165   467570.0  157297.0  39.0  ...             1.909637
# 53882     531850    9848   361308.0  160694.0  39.0  ...             1.851650
# ...          ...     ...        ...       ...   ...  ...                  ...
# 55216    3276630   40840        NaN       NaN  39.0  ...             1.243564
# 55042    3276630   40840        NaN       NaN  39.0  ...             1.243564
# 56608    3294521   40840        NaN       NaN  39.0  ...             1.239634
# 55912    3276630   40840        NaN       NaN  39.0  ...             1.243564
# 11756       6604     363        NaN       NaN  39.0  ...                  NaN
#
#               UID  ISO3  Testing_Rate  Hospitalization_Rate        Date  \
# 54926  84000039.0   USA  6.692936e-06                   NaN  2020-12-16
# 55274  84000039.0   USA  6.828255e-06                   NaN  2020-12-18
# 55100  84000039.0   USA  6.761601e-06                   NaN  2020-12-17
# 55970  84000039.0   USA  7.014998e-06                   NaN  2020-12-22
# 53882  84000039.0   USA  6.347023e-06                   NaN  2020-12-10
# ...           ...   ...           ...                   ...         ...
# 55216  84000039.0   USA           NaN                   NaN         NaN
# 55042  84000039.0   USA           NaN                   NaN         NaN
# 56608  84000039.0   USA           NaN                   NaN         NaN
# 55912  84000039.0   USA           NaN                   NaN         NaN
# 11756  84000039.0   USA  5.973514e-08             29.497274  2020-04-12
#
#        People_Tested  Mortality_Rate Date_converted  Daily_Deaths_Total
# 54926            NaN             NaN     2020-12-16               211.0
# 55274            NaN             NaN     2020-12-18               209.0
# 55100            NaN             NaN     2020-12-17               208.0
# 55970            NaN             NaN     2020-12-22               199.0
# 53882            NaN             NaN     2020-12-10               194.0
# ...              ...             ...            ...                 ...
# 55216            NaN             NaN            NaT                 0.0
# 55042            NaN             NaN            NaT                 0.0
# 56608            NaN             NaN            NaT                 0.0
# 55912            NaN             NaN            NaT                 0.0
# 11756        63243.0        5.496669     2020-04-12                 NaN
#
# [988 rows x 23 columns]

# %% [markdown]
# As you can see the highest number of deaths in Ohio were during 2nd and 3rd week of Decemeber 2020

# %% [markdown]
# Now can you do the same for Pennsylvania and check the spikes in Covid Death

# %% [markdown]
# Before we move into the next section we will calculate monthly Covid-19 death totals for Ohio. In order to do that we can apply groupby in Ohio stategroup using month and year as the key. Since we don't have month and year as seperate columns we can create them.

# %%
ohGroup['year'] = ohGroup['Date_converted'].dt.year
ohGroup['month'] = ohGroup['Date_converted'].dt.month
# Out:
# C:\Users\jxa421\AppData\Local\Temp\ipykernel_28144\3287235747.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohGroup['year'] = ohGroup['Date_converted'].dt.year
# C:\Users\jxa421\AppData\Local\Temp\ipykernel_28144\3287235747.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohGroup['month'] = ohGroup['Date_converted'].dt.month

# %%
#use year and month as keys
ohDateGrouped = ohGroup.groupby(['year','month'])

# %% [markdown]
# Now if you want to just get the data for March 2021

# %%
ohDateGrouped.get_group((2021,3))
# Out:
#       Province_State Country_Region          Last_Update      Lat    Long_  \
# 6884            Ohio             US  2021-03-02 05:30:53  40.3888 -82.7649
# 7000            Ohio             US  2021-03-03 05:30:49  40.3888 -82.7649
# 7116            Ohio             US  2021-03-04 05:30:41  40.3888 -82.7649
# 7232            Ohio             US  2021-03-05 05:31:07  40.3888 -82.7649
# 7348            Ohio             US  2021-03-06 04:30:38  40.3888 -82.7649
# 7464            Ohio             US  2021-03-07 05:31:30  40.3888 -82.7649
# 7580            Ohio             US  2021-03-08 05:31:09  40.3888 -82.7649
# 7696            Ohio             US  2021-03-09 05:30:55  40.3888 -82.7649
# 7812            Ohio             US  2021-03-10 05:31:08  40.3888 -82.7649
# 7928            Ohio             US  2021-03-11 05:30:58  40.3888 -82.7649
# 8044            Ohio             US  2021-03-12 05:30:41  40.3888 -82.7649
# 8160            Ohio             US  2021-03-13 05:30:48  40.3888 -82.7649
# 8276            Ohio             US  2021-03-14 05:31:09  40.3888 -82.7649
# 8392            Ohio             US  2021-03-15 05:31:06  40.3888 -82.7649
# 8508            Ohio             US  2021-03-16 05:31:04  40.3888 -82.7649
# 8624            Ohio             US  2021-03-17 05:31:00  40.3888 -82.7649
# 8740            Ohio             US  2021-03-18 05:31:01  40.3888 -82.7649
# 8856            Ohio             US  2021-03-19 05:30:59  40.3888 -82.7649
# 8972            Ohio             US  2021-03-20 05:31:09  40.3888 -82.7649
# 9088            Ohio             US  2021-03-21 05:30:52  40.3888 -82.7649
# 9204            Ohio             US  2021-03-22 05:30:46  40.3888 -82.7649
# 9320            Ohio             US  2021-03-23 05:31:19  40.3888 -82.7649
# 9436            Ohio             US  2021-03-24 05:31:13  40.3888 -82.7649
# 9552            Ohio             US  2021-03-25 05:30:43  40.3888 -82.7649
# 9668            Ohio             US  2021-03-26 05:30:37  40.3888 -82.7649
# 9784            Ohio             US  2021-03-27 05:31:28  40.3888 -82.7649
# 9900            Ohio             US  2021-03-28 05:31:16  40.3888 -82.7649
# 10016           Ohio             US  2021-03-29 04:31:08  40.3888 -82.7649
# 10132           Ohio             US  2021-03-30 04:31:00  40.3888 -82.7649
# 10248           Ohio             US  2021-03-31 04:31:15  40.3888 -82.7649
# 10364           Ohio             US  2021-04-01 04:30:33  40.3888 -82.7649
#
#        Confirmed  Deaths  Recovered   Active  FIPS  ...         UID  ISO3  \
# 6884      968874   18720   911474.0  38677.0  39.0  ...  84000039.0   USA
# 7000      970583   18749   914893.0  36938.0  39.0  ...  84000039.0   USA
# 7116      972605   18779   916592.0  37231.0  39.0  ...  84000039.0   USA
# 7232      974480   18806   919296.0  36375.0  39.0  ...  84000039.0   USA
# 7348      976230   18832   921707.0  35689.0  39.0  ...  84000039.0   USA
# 7464      977736   18853   921707.0  37174.0  39.0  ...  84000039.0   USA
# 7580      978471   18879        NaN      NaN  39.0  ...  84000039.0   USA
# 7696      979725   18902        NaN      NaN  39.0  ...  84000039.0   USA
# 7812      981618   18924        NaN      NaN  39.0  ...  84000039.0   USA
# 7928      983486   18949        NaN      NaN  39.0  ...  84000039.0   USA
# 8044      984934   18970        NaN      NaN  39.0  ...  84000039.0   USA
# 8160      986740   18993        NaN      NaN  39.0  ...  84000039.0   USA
# 8276      988298   19017        NaN      NaN  39.0  ...  84000039.0   USA
# 8392      989191   19032        NaN      NaN  39.0  ...  84000039.0   USA
# 8508      990340   19050        NaN      NaN  39.0  ...  84000039.0   USA
# 8624      992223   19064        NaN      NaN  39.0  ...  84000039.0   USA
# 8740      993681   19080        NaN      NaN  39.0  ...  84000039.0   USA
# 8856      995785   19097        NaN      NaN  39.0  ...  84000039.0   USA
# 8972      997336   19119        NaN      NaN  39.0  ...  84000039.0   USA
# 9088      998819   19135        NaN      NaN  39.0  ...  84000039.0   USA
# 9204      999750   19152        NaN      NaN  39.0  ...  84000039.0   USA
# 9320     1001194   19166        NaN      NaN  39.0  ...  84000039.0   USA
# 9436     1002822   19177        NaN      NaN  39.0  ...  84000039.0   USA
# 9552     1004670   19189        NaN      NaN  39.0  ...  84000039.0   USA
# 9668     1006171   19209        NaN      NaN  39.0  ...  84000039.0   USA
# 9784     1008913   19223        NaN      NaN  39.0  ...  84000039.0   USA
# 9900     1010603   19237        NaN      NaN  39.0  ...  84000039.0   USA
# 10016    1011622   19249        NaN      NaN  39.0  ...  84000039.0   USA
# 10132    1013119   19261        NaN      NaN  39.0  ...  84000039.0   USA
# 10248    1015577   19273        NaN      NaN  39.0  ...  84000039.0   USA
# 10364    1017566   19291        NaN      NaN  39.0  ...  84000039.0   USA
#
#        Testing_Rate  Hospitalization_Rate        Date People_Tested  \
# 6884       0.000010                   NaN  2021-03-01           NaN
# 7000       0.000010                   NaN  2021-03-02           NaN
# 7116       0.000010                   NaN  2021-03-03           NaN
# 7232       0.000011                   NaN  2021-03-04           NaN
# 7348       0.000011                   NaN  2021-03-05           NaN
# 7464       0.000011                   NaN  2021-03-06           NaN
# 7580       0.000011                   NaN  2021-03-07           NaN
# 7696       0.000011                   NaN  2021-03-08           NaN
# 7812       0.000011                   NaN  2021-03-09           NaN
# 7928       0.000011                   NaN  2021-03-10           NaN
# 8044       0.000011                   NaN  2021-03-11           NaN
# 8160       0.000011                   NaN  2021-03-12           NaN
# 8276       0.000011                   NaN  2021-03-13           NaN
# 8392       0.000011                   NaN  2021-03-14           NaN
# 8508       0.000011                   NaN  2021-03-15           NaN
# 8624       0.000011                   NaN  2021-03-16           NaN
# 8740       0.000011                   NaN  2021-03-17           NaN
# 8856       0.000011                   NaN  2021-03-18           NaN
# 8972       0.000011                   NaN  2021-03-19           NaN
# 9088       0.000011                   NaN  2021-03-20           NaN
# 9204       0.000011                   NaN  2021-03-21           NaN
# 9320       0.000011                   NaN  2021-03-22           NaN
# 9436       0.000011                   NaN  2021-03-23           NaN
# 9552       0.000011                   NaN  2021-03-24           NaN
# 9668       0.000011                   NaN  2021-03-25           NaN
# 9784       0.000011                   NaN  2021-03-26           NaN
# 9900       0.000011                   NaN  2021-03-27           NaN
# 10016      0.000012                   NaN  2021-03-28           NaN
# 10132      0.000012                   NaN  2021-03-29           NaN
# 10248      0.000012                   NaN  2021-03-30           NaN
# 10364      0.000012                   NaN  2021-03-31           NaN
#
#        Mortality_Rate  Date_converted    year  month
# 6884              NaN      2021-03-01  2021.0    3.0
# 7000              NaN      2021-03-02  2021.0    3.0
# 7116              NaN      2021-03-03  2021.0    3.0
# 7232              NaN      2021-03-04  2021.0    3.0
# 7348              NaN      2021-03-05  2021.0    3.0
# 7464              NaN      2021-03-06  2021.0    3.0
# 7580              NaN      2021-03-07  2021.0    3.0
# 7696              NaN      2021-03-08  2021.0    3.0
# 7812              NaN      2021-03-09  2021.0    3.0
# 7928              NaN      2021-03-10  2021.0    3.0
# 8044              NaN      2021-03-11  2021.0    3.0
# 8160              NaN      2021-03-12  2021.0    3.0
# 8276              NaN      2021-03-13  2021.0    3.0
# 8392              NaN      2021-03-14  2021.0    3.0
# 8508              NaN      2021-03-15  2021.0    3.0
# 8624              NaN      2021-03-16  2021.0    3.0
# 8740              NaN      2021-03-17  2021.0    3.0
# 8856              NaN      2021-03-18  2021.0    3.0
# 8972              NaN      2021-03-19  2021.0    3.0
# 9088              NaN      2021-03-20  2021.0    3.0
# 9204              NaN      2021-03-21  2021.0    3.0
# 9320              NaN      2021-03-22  2021.0    3.0
# 9436              NaN      2021-03-23  2021.0    3.0
# 9552              NaN      2021-03-24  2021.0    3.0
# 9668              NaN      2021-03-25  2021.0    3.0
# 9784              NaN      2021-03-26  2021.0    3.0
# 9900              NaN      2021-03-27  2021.0    3.0
# 10016             NaN      2021-03-28  2021.0    3.0
# 10132             NaN      2021-03-29  2021.0    3.0
# 10248             NaN      2021-03-30  2021.0    3.0
# 10364             NaN      2021-03-31  2021.0    3.0
#
# [31 rows x 24 columns]

# %% [markdown]
# If you want to get the monthly death totals you need to apply the max() method as the death totals are cumulative.

# %%
monthlyDeathTotals = ohDateGrouped['Deaths'].max()

# %%
monthlyDeathTotals
# Out:
# year    month
# 2020.0  4.0       1083
#         5.0       2134
#         6.0       2601
#         7.0       3209
#         8.0       3913
#         9.0       4471
#         10.0      5325
#         11.0      8084
#         12.0     13621
# 2021.0  1.0      17325
#         2.0      18691
#         3.0      19291
#         4.0      19846
#         5.0      20306
#         6.0      20541
#         7.0      20706
#         8.0      21442
#         9.0      23616
#         10.0     26100
#         11.0     28141
#         12.0     31898
# 2022.0  1.0      36289
#         2.0      38022
#         3.0      38497
#         4.0      38646
#         5.0      38817
#         6.0      39045
#         7.0      39347
#         8.0      39775
#         9.0      40010
# Name: Deaths, dtype: int64

# %% [markdown]
# This is a series object with multiple indexes (or Multi Index). If you want to convert it into a DataFrame you can use the reset_index() method.

# %%
monthlyDeathTotals = monthlyDeathTotals.reset_index()

# %%
monthlyDeathTotals
# Out:
#       year  month  Deaths
# 0   2020.0    4.0    1083
# 1   2020.0    5.0    2134
# 2   2020.0    6.0    2601
# 3   2020.0    7.0    3209
# 4   2020.0    8.0    3913
# 5   2020.0    9.0    4471
# 6   2020.0   10.0    5325
# 7   2020.0   11.0    8084
# 8   2020.0   12.0   13621
# 9   2021.0    1.0   17325
# 10  2021.0    2.0   18691
# 11  2021.0    3.0   19291
# 12  2021.0    4.0   19846
# 13  2021.0    5.0   20306
# 14  2021.0    6.0   20541
# 15  2021.0    7.0   20706
# 16  2021.0    8.0   21442
# 17  2021.0    9.0   23616
# 18  2021.0   10.0   26100
# 19  2021.0   11.0   28141
# 20  2021.0   12.0   31898
# 21  2022.0    1.0   36289
# 22  2022.0    2.0   38022
# 23  2022.0    3.0   38497
# 24  2022.0    4.0   38646
# 25  2022.0    5.0   38817
# 26  2022.0    6.0   39045
# 27  2022.0    7.0   39347
# 28  2022.0    8.0   39775
# 29  2022.0    9.0   40010

# %% [markdown]
# Now if we want to see the change in totals you can apply the diff() method

# %%
monthlyDeathTotals['change'] = monthlyDeathTotals.Deaths.diff()
monthlyDeathTotals
# Out:
#       year  month  Deaths  change
# 0   2020.0    4.0    1083     NaN
# 1   2020.0    5.0    2134  1051.0
# 2   2020.0    6.0    2601   467.0
# 3   2020.0    7.0    3209   608.0
# 4   2020.0    8.0    3913   704.0
# 5   2020.0    9.0    4471   558.0
# 6   2020.0   10.0    5325   854.0
# 7   2020.0   11.0    8084  2759.0
# 8   2020.0   12.0   13621  5537.0
# 9   2021.0    1.0   17325  3704.0
# 10  2021.0    2.0   18691  1366.0
# 11  2021.0    3.0   19291   600.0
# 12  2021.0    4.0   19846   555.0
# 13  2021.0    5.0   20306   460.0
# 14  2021.0    6.0   20541   235.0
# 15  2021.0    7.0   20706   165.0
# 16  2021.0    8.0   21442   736.0
# 17  2021.0    9.0   23616  2174.0
# 18  2021.0   10.0   26100  2484.0
# 19  2021.0   11.0   28141  2041.0
# 20  2021.0   12.0   31898  3757.0
# 21  2022.0    1.0   36289  4391.0
# 22  2022.0    2.0   38022  1733.0
# 23  2022.0    3.0   38497   475.0
# 24  2022.0    4.0   38646   149.0
# 25  2022.0    5.0   38817   171.0
# 26  2022.0    6.0   39045   228.0
# 27  2022.0    7.0   39347   302.0
# 28  2022.0    8.0   39775   428.0
# 29  2022.0    9.0   40010   235.0

# %% [markdown]
# In the next section we will learn about joining multiple files (not concatenating) which is a key data analysis procedure.
